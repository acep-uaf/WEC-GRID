# %% [markdown]
# <figure style="text-align: center;">
#     <img src="../../docs/wec-grid-logo.png" alt="Alt text">
#     <figcaption>WEC-GRID logo</figcaption>
# </figure>

# %% [markdown]
# <div align="center">
#
# # Integration of Wave and Current Energy Converters into Microgrids demonstration
#
# </div>
#
# ---
#
# ### Introduction
#
# In light of the transition towards sustainable energy solutions, **Wave Energy Converters (WECs)** and **Current Energy Converters (CECs)** stand out as pivotal innovations. These technologies offer the potential to harness the vast energy of our oceans. However, their integration into complex systems such as microgrids necessitates rigorous modeling, testing, and analysis. This Jupyter notebook serves as both a demonstration and guide, leveraging an open-source software to address these integration challenges.
#
# ---
#
# ### Use Case Scenario
#
# The following scenario provides a practical backdrop for our exploration:
#
# - **Grid**: 'Area 1' of the RTS 96 system—a standard in power system testing Figure 1.
# - **Devices**:
#   - Wave Energy Converters: 'LUPA' model.
#   - Current Energy Converter: 'placeholder'.
#
# ---
#
# ### Moving forward
#
# Navigating through this notebook, we will:
# - Run detailed simulations to observe the interactions of the WECs and CEC within a microgrid setting.
# - Highlight key features of the software that facilitate smooth integration using 3rd party modelers.
# - Identify potential stability or compatibility challenges using built in tools
#
#
#
# ---

# %% [markdown]
# <figure style="text-align: center;">
#     <img src="../../docs/The-IEEE-RTS-96-system.png" alt="RTS96 Area 1 (Official)" width="500">
#     <figcaption>Figure 1: RTS96 Area 1 (Official) <br><cite>Source: <a href="https://www.researchgate.net/figure/The-IEEE-RTS-96-system_fig5_3213080">ResearchGate Article</a></cite></figcaption>
# </figure>

# %% [markdown]
# <figure style="text-align: center;">
#     <img src="../../docs/WecGrid-flowchart.png" alt="" width="800">
#     <figcaption>Figure 2: Wec-Grid flow chart </figcaption>
# </figure>

# %% [markdown]
# ---
# ### WEC-GRID Initialization
#
# In the cell below we initalize the Wec_grid software by passing a grid topology model. This raw file can be used by the two supported Powerflow solvers softwares PSSE and pyPSA. The communication is being handled by WEC-GRID.
#
# ### PSS®E, Powerflow Solvers
#
# **PSS®E (Power System Simulator for Engineering)** is an industry-standard software application tailored for the analysis and simulation of power systems. Developed by Siemens, PSS®E provides power engineers with tools to simulate and investigate the response of complex power systems to various disturbances. It plays a pivotal role in diverse grid studies, from routine network examinations to specialized research projects.
#
# In the context of our current operations:
# - `WecObj.initialize_psse("fnsl")` initializes PSS®E with a specific solver, in this instance, `"fnsl"`.

# %%
"""
Imports 
"""
import WEC_GRID as wg  # import the WEC-GRID software
import numpy as np
import pandas as pd


WecObj = wg.Wec_grid(
    "../models/grid_models/IEEE_24_bus.RAW"
)  # initialize Object with Grid file (figure 1)

WecObj.initalize_psse("fnsl")  # initalize PSSe with solver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 """
#       2 Imports
#       3 """
# ----> 4 import WEC_GRID as wg  # import the WEC-GRID software
#       5 import numpy as np
#       6 import pandas as pd
#
# ModuleNotFoundError: No module named 'WEC_GRID'

# %% [markdown]
# ---
#
# ### Reviewing Grid Data using Pandas DataFrame
#
# In the subsequent cell, we utilize the dot operator to access and visualize the grid data encapsulated within the `WecObj` instance. The choice of using **Pandas** for this representation is influenced by its rich feature set, enabling efficient data manipulation and analysis.
#
# To review the system data in Pandas DataFrame format, execute:

# %%
WecObj.psse_dataframe  # review system data in pandas format
# Out:
#     BUS_ID     Bus   BASE        PU     ANGLED  Type       P Gen       Q Gen  \
# 0        1   BUS 1  138.0  1.000000   0.000000     3   35.930069  180.488586
# 1        2   BUS 2  138.0  0.997822   0.010373     2   67.000000    0.000000
# 2        3   BUS 3  138.0  0.863703  10.755864     1         NaN         NaN
# 3        4   BUS 4  138.0  0.887014  -0.415208     1         NaN         NaN
# 4        5   BUS 5  138.0  0.927217  -0.229420     1         NaN         NaN
# 5        6   BUS 6  138.0  0.907952   0.391817     1         NaN         NaN
# 6        7   BUS 7  138.0  0.796234  -0.580059     2   64.000000    0.000000
# 7        8   BUS 8  230.0  0.805368  -0.868408     1         NaN         NaN
# 8        9   BUS 9  138.0  0.834940   4.989085     1         NaN         NaN
# 9       10  BUS 10  138.0  0.881702   3.723669     1         NaN         NaN
# 10      11  BUS 11  230.0  0.836073  12.640563     1         NaN         NaN
# 11      12  BUS 12  230.0  0.839763  11.783456     1         NaN         NaN
# 12      13  BUS 13  230.0  0.836927  15.450583     2  200.000000    0.000000
# 13      14  BUS 14  230.0  0.836423  18.757851     2    0.000000    0.000000
# 14      15  BUS 15  230.0  0.885209  33.212997     2  274.000000    0.000000
# 15      16  BUS 16  230.0  0.862146  27.084261     2  245.000000    0.000000
# 16      17  BUS 17  230.0  0.895736  32.061146     1         NaN         NaN
# 17      18  BUS 18  230.0  0.901057  33.899288     2  144.000000    0.000000
# 18      19  BUS 19  230.0  0.851835  23.804094     1         NaN         NaN
# 19      20  BUS 20  230.0  0.849352  22.331301     1         NaN         NaN
# 20      21  BUS 21  230.0  0.911253  35.657959     2  294.000000    0.000000
# 21      22  BUS 22  230.0  1.000000  37.502068     2  150.000000  199.455856
# 22      23  BUS 23  230.0  0.849713  22.079517     2  200.000000    0.000000
# 23      24  BUS 24  230.0  0.854969  24.813110     1         NaN         NaN
#
#     P Load     Q Load           P           Q        ΔP            ΔQ  \
# 0      NaN        NaN   35.930069  180.488586  0.000000 -1.192093e-05
# 1     97.0  20.000000  -30.000000  -20.000000  0.000000  0.000000e+00
# 2     90.0  19.000000  -90.000000  -19.000000 -0.000012  0.000000e+00
# 3     74.0  15.000001  -74.000000  -15.000001  0.000003 -5.960464e-06
# 4     71.0  14.000000  -71.000000  -14.000000  0.000000  0.000000e+00
# 5     68.0  14.000000  -68.000000  -14.000000 -0.000002 -5.960464e-06
# 6     62.0  13.000000    2.000000  -13.000000  0.000000  0.000000e+00
# 7     85.0  18.000000  -85.000000  -18.000000 -0.000001 -7.450581e-07
# 8    175.0  36.000000 -175.000000  -36.000000 -0.000006  2.235174e-06
# 9    100.0  23.000000 -100.000000  -23.000000  0.000003  0.000000e+00
# 10     NaN        NaN         NaN         NaN  0.000000  0.000000e+00
# 11     NaN        NaN         NaN         NaN  0.000000 -2.980232e-06
# 12   130.0  27.000002   70.000000  -27.000002  0.000000  0.000000e+00
# 13    92.0  20.000000  -92.000000  -20.000000 -0.000012  0.000000e+00
# 14   158.0  32.000000  116.000000  -32.000000  0.000000  2.980232e-06
# 15   100.0  20.000000  145.000000  -20.000000 -0.000018  2.980232e-06
# 16     NaN        NaN         NaN         NaN  0.000000  5.960464e-06
# 17   162.0  34.000000  -18.000000  -34.000000  0.000000  0.000000e+00
# 18    90.0  18.000000  -90.000000  -18.000000  0.000000 -7.450581e-07
# 19    65.0  13.000000  -65.000000  -13.000000  0.000006  7.450581e-07
# 20     NaN        NaN  294.000000    0.000000  0.000024 -2.980232e-06
# 21     NaN        NaN  150.000000  199.455856  0.000000 -1.192093e-05
# 22     NaN        NaN  200.000000    0.000000  0.000000 -7.450581e-07
# 23     NaN        NaN         NaN         NaN  0.000000  0.000000e+00
#
#          M_Angle     M_Mag
# 0   1.192093e-05 -1.570796
# 1   0.000000e+00  0.000000
# 2   1.192093e-05  3.141593
# 3   6.664002e-06 -1.107149
# 4   0.000000e+00  0.000000
# 5   6.365779e-06 -1.929567
# 6   0.000000e+00  0.000000
# 7   1.343173e-06 -2.553590
# 8   6.365779e-06  2.782822
# 9   2.980232e-06  0.000000
# 10  0.000000e+00  0.000000
# 11  2.980232e-06 -1.570796
# 12  0.000000e+00  0.000000
# 13  1.192093e-05  3.141593
# 14  2.980232e-06  1.570796
# 15  1.812804e-05  2.976444
# 16  5.960464e-06  1.570796
# 17  0.000000e+00  0.000000
# 18  7.450581e-07 -1.570796
# 19  6.006850e-06  0.124355
# 20  2.402740e-05 -0.124355
# 21  1.192093e-05 -1.570796
# 22  7.450581e-07 -1.570796
# 23  0.000000e+00  0.000000

# %% [markdown]
# ---
#
# ### Integrating WEC and CEC into the Power Grid
#
# Using the functions `create_wec` and `create_cec`, we can seamlessly introduce Wave Energy Converters (WECs) and Current Energy Converters (CECs) to specific bus locations within our grid system.
#
# In the provided code:
#
# - `WecObj.create_wec(ID=1, model="LUPA", bus_location=21)`: A WEC with the model name "LUPA" is integrated at bus 21.
# - `WecObj.create_wec(ID=2, model="LUPA", bus_location=2)`: Another WEC, again of the "LUPA" model, is integrated at bus 2.
# - `WecObj.create_wec(ID=3, model="LUPA", bus_location=7)`: A third WEC with the "LUPA" model is placed at bus 7.
# - `WecObj.create_cec(ID=6, model="CEC", bus_location=14)`: A CEC is integrated at bus 14.
#
# As illustrated in **Figure 2**, the functions retrieve necessary data and parameters for each WEC and CEC from a shared SQL database. This ensures that each converter is modeled accurately based on existing data, providing a realistic simulation environment. This also allows for simulations to be ran only when neccessary.

# %%
# create WEC / CECs
WecObj.create_wec(ID=11, model="RM3", bus_location=7)
WecObj.create_cec(ID=6, model="cec", bus_location=2)

# WEC farm
for wec in WecObj.wec_list:
    wec.dataframe["pg"] = wec.dataframe["pg"] * 10

# %% [markdown]
# ---
# ### Visualizing the Power Grid with `viz()`
#
# The function `WecObj.viz()` provides a dynamic visualization of the power grid. This visual representation is instrumental in offering an intuitive understanding of the grid's structure, its components, and their respective characteristics.
#
# In this visualization:
# - **Green**: Represents a **PV Bus**. These buses are where the system voltage magnitude is controlled by adjusting the real power output of the machine, typically a generator, to the system.
# - **Grey**: Denotes a **PQ Bus**. These are load buses where both active (P) and reactive (Q) powers are specified.
# - **Red**: Signifies a **Swing Bus**. This bus acts as a reference in the power system, and its voltage magnitude and angle are predefined. All power system calculations are based relative to this bus.
# - **Blue**: Represents a bus with **WEC or CEC**. These buses are designated for the integration of Wave Energy Converters (WECs) or Current Energy Converters (CECs) into the grid.
#
# Understanding these bus types and their representations is crucial for anyone involved in power system studies. The color-coded visualization provides a rapid, high-level understanding of grid dynamics and can aid in pinpointing areas of interest or potential issues.

# %%
WecObj._psse_viz()
# Out:
# VBox(children=(Dropdown(description='Bus Type:', options=(('All', 0), ('PQ Bus', 1), ('PV Bus', 2), ('Swing Bu…

# %% [markdown]
# ---
# ### Integration with WEC-SIM and the LUPA Model
#
# The function `run_WEC_Sim` integrates with the renowned MATLAB-based software, **WEC-SIM** (Wave Energy Converter SIMulator). WEC-SIM is a time-domain modeling tool developed for wave energy converters. It facilitates the study of these converters' dynamics and their responses to waves, allowing for a comprehensive analysis of their performance.
#
# For our simulations, we utilize the **LUPA** model. When calling `run_WEC_Sim`, the function internally invokes the MATLAB engine, seamlessly bridging our Python environment with the capabilities of MATLAB and WEC-SIM. This integration ensures that our simulations leverage the robustness and accuracy of the LUPA model within WEC-SIM, providing results that are both reliable and reflective of real-world scenarios.
#
#
# ### Running WEC-SIM / CEC
#
# To run the simulation for the Wave Energy Converters (WECs) and Current Energy Converters (CECs) integrated into the grid, we'd typically use the following setup and commands:
#
# ```python
# config = {
#     "simLength": 60 * 60 * 8,         # Simulation length of 8 hours
#     "Tsample": 300,                   # Sampling time of 5 minutes
#     "waveHeight": 2.5,                # Wave height in meters
#     "wavePeriod": 8,                  # Wave period in seconds
#     "waveSeed": np.random.randint(999999999),   # Random seed for wave patterns
# }
#
# # Run the simulation for WEC with ID=1
# config["wec_id"] = 1
# WecObj.run_WEC_Sim(wec_id=1, sim_config=config)
#
# # Run the simulation for WEC with ID=2
# config["wec_id"] = 2
# WecObj.run_WEC_Sim(wec_id=2, sim_config=config)
#
# # Run the simulation for WEC with ID=3
# config["wec_id"] = 3
# WecObj.run_WEC_Sim(wec_id=3, sim_config=config)
#
# # Run the simulation for CEC with ID=6 with a different simulation length
# WecObj.run_CEC_Sim(6, sim_config={"sim_length": 1200})  # Simulation length of 20 minutes
# ```

# %% [markdown]
# ---
# ### Generating Load Curves Based on Peak Values
#
# Load curves provide essential insights into how the electrical load varies over a specific period, usually daily. They depict the power demand in the grid at different times and are crucial for planning, designing, and operating power systems. Using the Wec-Grid function below we can create basic load curves based on known peak load values.

# %%
peak_values = {
    1: 0,
    2: 97.000,
    3: 90.000,
    4: 74.000,
    5: 71.000,
    6: 68.000,
    7: 62.000,
    8: 85.000,
    9: 175.000,
    10: 100.000,
    11: 0,
    12: 0,
    13: 130.000,
    14: 92.000,
    15: 158.000,
    16: 100.000,
    17: 0,
    18: 162.000,
    19: 90.000,
    20: 65.000,
    21: 0,
    22: 0,
    23: 0,
    24: 0,
}

WecObj._generate_all_load_profiles(
    peak_values, curve_type="summer", noise_type="gaussian", noise_level=2
)
WecObj.plot_load_curve(bus_id=2)

# %% [markdown]
# ---
# ### Integration Simulation via AC Injection
#
# The next stage of our analysis involves the integration of the results from the WEC-SIM simulation into our grid model. This is achieved through an AC injection method. AC injection allows us to simulate the addition of active and reactive power into our grid based on the outputs from the Wave Energy Converters. The output is console output from PSSe

# %%
time = WecObj.wec_list[0].dataframe.time.to_list()[-1]
WecObj._psse_ac_injection(start=0, end=(time))
# Out:
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     64.0000         0.00000      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.796234         1.00000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     62.0000        -2.32370      PL
#     13.0000         0.00000      QL
#  "            "  "CONSTP      "  LODTYP
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.8271(      7     )    2.9554(      7     )
#                                                              0.19602(      8     )   0.06823(     21     )
#    1         0.2074(      8     )    0.5923(      8     )
#                                                              0.11937(      7     )   0.04251(     21     )
#    2         0.0412(      8     )    0.0608(      8     )
#                                                              0.02300(      7     )   0.01203(     21     )
#    3         0.0019(      8     )    0.0013(      8     )
#                                                              0.00083(      7     )   0.00061(     21     )
#    4         0.0000(      8     )    0.0000(     16     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.00 MW      0.00 Mvar      0.00 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      32.5   1000.0     0.0     158.6   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     0.00000        0.969581      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.833845         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -2.32370        0.700431      PL
#
#  Power flow data changed for machine "1" at bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     67.0000         1.73024      PG
#
#  Power flow data changed for bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.997969         1.10000      VM
#
#  Power flow data changed for load "1" at bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     97.0000        -2.94671      PL
#     20.0000         0.00000      QL
#  "            "  "CONSTP      "  LODTYP
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0        39.2095(      2     )   70.0694(      2     )
#                                                              0.28634(      8     )   0.10149(     21     )
#    1         2.9879(      2     )    5.3517(      2     )
#                                                              0.17780(      7     )   0.06726(     21     )
#    2         0.1129(      8     )    0.1821(      8     )
#                                                              0.05556(      7     )   0.02962(     21     )
#    3         0.0118(      8     )    0.0095(      8     )
#                                                              0.00525(      7     )   0.00382(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.08 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      -0.1*  1000.0     0.0     138.9   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.969581        0.874755      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.832318         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.700431       -0.939712      PL
#
#  Power flow data changed for machine "1" at bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     1.73024         1.82127      PG
#
#  Power flow data changed for bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.998445         1.10000      VM
#
#  Power flow data changed for load "1" at bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -2.94671         3.99188      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0        39.4752(      2     )   69.9613(      2     )
#                                                              0.29548(      8     )   0.10240(     21     )
#    1         3.0068(      2     )    5.3444(      2     )
#                                                              0.17906(      7     )   0.06832(     21     )
#    2         0.1196(      8     )    0.1920(      8     )
#                                                              0.05676(      7     )   0.03048(     21     )
#    3         0.0127(      8     )    0.0103(      8     )
#                                                              0.00552(      7     )   0.00404(     21     )
#    4         0.0002(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.02 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.09 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       5.1   1000.0     0.0     138.5   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.874755        0.813793      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.833728         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#   -0.939712        -2.06633      PL
#
#  Power flow data changed for machine "1" at bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     1.82127         1.82421      PG
#
#  Power flow data changed for bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.998406         1.10000      VM
#
#  Power flow data changed for load "1" at bus 2 [2           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     3.99188        0.634250      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0        39.3813(      2     )   69.9883(      2     )
#                                                              0.28908(      8     )   0.10046(     21     )
#    1         3.0000(      2     )    5.3463(      2     )
#                                                              0.17738(      7     )   0.06735(     21     )
#    2         0.1156(      8     )    0.1842(      8     )
#                                                              0.05526(      7     )   0.02963(     21     )
#    3         0.0120(      8     )    0.0096(      8     )
#                                                              0.00519(      7     )   0.00379(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.08 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       0.6   1000.0     0.0     138.2   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.813793        0.799488      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.834715         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -2.06633        -1.19838      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1998(      7     )    4.4663(      7     )
#                                                              0.26031(      8     )   0.08633(     21     )
#    1         0.3923(      8     )    1.1158(      8     )
#                                                              0.16964(      7     )   0.05872(     21     )
#    2         0.0944(      8     )    0.1543(      8     )
#                                                              0.04972(      7     )   0.02463(     21     )
#    3         0.0089(      8     )    0.0072(      8     )
#                                                              0.00398(      7     )   0.00275(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.04 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       1.6   1000.0     0.0     138.5   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.799488        0.918248      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.833889         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -1.19838        -2.07557      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1819(      7     )    4.4802(      7     )
#                                                              0.26525(      8     )   0.08690(     21     )
#    1         0.4071(      8     )    1.1439(      8     )
#                                                              0.17031(      7     )   0.05931(     21     )
#    2         0.0977(      8     )    0.1591(      8     )
#                                                              0.05029(      7     )   0.02505(     21     )
#    3         0.0093(      8     )    0.0075(      8     )
#                                                              0.00409(      7     )   0.00283(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.05 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       0.5   1000.0     0.0     138.2   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.918248        0.858687      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.834801         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -2.07557       -0.252161      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2098(      7     )    4.4649(      7     )
#                                                              0.25909(      8     )   0.08653(     21     )
#    1         0.3877(      8     )    1.1094(      8     )
#                                                              0.16973(      7     )   0.05864(     21     )
#    2         0.0934(      8     )    0.1534(      8     )
#                                                              0.04977(      7     )   0.02460(     21     )
#    3         0.0088(      8     )    0.0071(      8     )
#                                                              0.00400(      7     )   0.00274(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.04 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       2.5   1000.0     0.0     138.7   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.858687        0.897893      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.833068         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#   -0.252161        0.995892      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2048(      7     )    4.4940(      7     )
#                                                              0.26627(      8     )   0.08852(     21     )
#    1         0.4057(      8     )    1.1523(      8     )
#                                                              0.17173(      7     )   0.05972(     21     )
#    2         0.0974(      8     )    0.1614(      8     )
#                                                              0.05143(      7     )   0.02549(     21     )
#    3         0.0094(      8     )    0.0078(      8     )
#                                                              0.00432(      7     )   0.00296(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.05 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       3.8   1000.0     0.0     139.0   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.897893        0.913589      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.831940         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.995892         2.07758      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2046(      7     )    4.5130(      7     )
#                                                              0.27078(      8     )   0.08993(     21     )
#    1         0.4167(      8     )    1.1799(      8     )
#                                                              0.17310(      7     )   0.06043(     21     )
#    2         0.0999(      8     )    0.1667(      8     )
#                                                              0.05258(      7     )   0.02608(     21     )
#    3         0.0098(      8     )    0.0083(      8     )
#                                                              0.00455(      7     )   0.00312(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.05 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       5.0   1000.0     0.0     139.3   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.913589        0.852862      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.830930         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     2.07758         2.99759      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2048(      7     )    4.5300(      7     )
#                                                              0.27486(      8     )   0.09124(     21     )
#    1         0.4266(      8     )    1.2051(      8     )
#                                                              0.17433(      7     )   0.06107(     21     )
#    2         0.1022(      8     )    0.1715(      8     )
#                                                              0.05363(      7     )   0.02663(     21     )
#    3         0.0101(      8     )    0.0087(      8     )
#                                                              0.00477(      7     )   0.00326(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.06 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       6.1   1000.0     0.0     139.6   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.852862        0.894316      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.829990         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     2.99759         3.33621      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1989(      7     )    4.5459(      7     )
#                                                              0.27937(      8     )   0.09234(     21     )
#    1         0.4387(      8     )    1.2325(      8     )
#                                                              0.17537(      7     )   0.06170(     21     )
#    2         0.1050(      8     )    0.1766(      8     )
#                                                              0.05454(      7     )   0.02715(     21     )
#    3         0.0105(      8     )    0.0091(      8     )
#                                                              0.00496(      7     )   0.00340(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.06 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       6.4   1000.0     0.0     139.6   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.894316        0.887172      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.829705         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     3.33621         5.39429      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2169(      7     )    4.5507(      7     )
#                                                              0.27868(      8     )   0.09313(     21     )
#    1         0.4339(      8     )    1.2300(      8     )
#                                                              0.17607(      7     )   0.06180(     21     )
#    2         0.1039(      8     )    0.1768(      8     )
#                                                              0.05512(      7     )   0.02732(     21     )
#    3         0.0105(      8     )    0.0093(      8     )
#                                                              0.00509(      7     )   0.00347(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.07 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       8.6   1000.0     0.0     140.3   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.887172        0.849914      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.827676         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     5.39429         4.50039      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1898(      7     )    4.5848(      7     )
#                                                              0.29031(      8     )   0.09532(     21     )
#    1         0.4677(      8     )    1.3004(      8     )
#                                                              0.17806(      7     )   0.06329(     21     )
#    2         0.1116(      8     )    0.1896(      8     )
#                                                              0.05694(      7     )   0.02848(     21     )
#    3         0.0116(      8     )    0.0103(      8     )
#                                                              0.00549(      7     )   0.00376(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.08 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       7.7   1000.0     0.0     140.0   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.849914        0.935891      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.828532         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     4.50039         3.91256      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1907(      7     )    4.5704(      7     )
#                                                              0.28644(      8     )   0.09412(     21     )
#    1         0.4577(      8     )    1.2761(      8     )
#                                                              0.17702(      7     )   0.06270(     21     )
#    2         0.1093(      8     )    0.1848(      8     )
#                                                              0.05601(      7     )   0.02798(     21     )
#    3         0.0112(      8     )    0.0099(      8     )
#                                                              0.00528(      7     )   0.00362(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.07 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       7.0   1000.0     0.0     139.8   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.935891        0.898817      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.829189         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     3.91256         7.23830      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2304(      7     )    4.5593(      7     )
#                                                              0.27941(      8     )   0.09412(     21     )
#    1         0.4334(      8     )    1.2359(      8     )
#                                                              0.17697(      7     )   0.06207(     21     )
#    2         0.1038(      8     )    0.1784(      8     )
#                                                              0.05590(      7     )   0.02762(     21     )
#    3         0.0106(      8     )    0.0095(      8     )
#                                                              0.00526(      7     )   0.00357(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.07 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      10.7   1000.0     0.0     140.9   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.898817        0.900544      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.825833         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     7.23830         5.96328      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1876(      7     )    4.6158(      7     )
#                                                              0.29887(      8     )   0.09794(     21     )
#    1         0.4899(      8     )    1.3550(      8     )
#                                                              0.18030(      7     )   0.06457(     21     )
#    2         0.1168(      8     )    0.2002(      8     )
#                                                              0.05900(      7     )   0.02958(     21     )
#    3         0.0124(      8     )    0.0113(      8     )
#                                                              0.00598(      7     )   0.00409(     21     )
#    4         0.0002(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.02 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.09 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       9.3   1000.0     0.0     140.4   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.900544        0.881158      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.827137         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     5.96328         5.99212      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1994(      7     )    4.5939(      7     )
#                                                              0.29160(      8     )   0.09626(     21     )
#    1         0.4692(      8     )    1.3096(      8     )
#                                                              0.17889(      7     )   0.06359(     21     )
#    2         0.1120(      8     )    0.1917(      8     )
#                                                              0.05769(      7     )   0.02879(     21     )
#    3         0.0117(      8     )    0.0106(      8     )
#                                                              0.00567(      7     )   0.00387(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.08 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       9.3   1000.0     0.0     140.4   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.881158        0.834504      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.827083         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     5.99212         9.39495      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2335(      7     )    4.5948(      7     )
#                                                              0.28809(      8     )   0.09707(     21     )
#    1         0.4545(      8     )    1.2907(      8     )
#                                                              0.17962(      7     )   0.06344(     21     )
#    2         0.1086(      8     )    0.1893(      8     )
#                                                              0.05830(      7     )   0.02884(     21     )
#    3         0.0114(      8     )    0.0106(      8     )
#                                                              0.00582(      7     )   0.00393(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.09 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      13.1   1000.0     0.0     141.6   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.834504        0.848264      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.823550         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     9.39495         9.87234      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2075(      7     )    4.6543(      7     )
#                                                              0.30724(      8     )   0.10175(     21     )
#    1         0.5081(      8     )    1.4111(      8     )
#                                                              0.18349(      7     )   0.06605(     21     )
#    2         0.1210(      8     )    0.2121(      8     )
#                                                              0.06200(      7     )   0.03100(     21     )
#    3         0.0133(      8     )    0.0127(      8     )
#                                                              0.00674(      7     )   0.00457(     21     )
#    4         0.0002(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.02 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.12 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      13.6   1000.0     0.0     141.8   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.848264        0.944162      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.823083         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     9.87234         10.2152      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2058(      7     )    4.6621(      7     )
#                                                              0.30964(      8     )   0.10241(     21     )
#    1         0.5146(      8     )    1.4267(      8     )
#                                                              0.18404(      7     )   0.06639(     21     )
#    2         0.1225(      8     )    0.2151(      8     )
#                                                              0.06253(      7     )   0.03130(     21     )
#    3         0.0136(      8     )    0.0130(      8     )
#                                                              0.00688(      7     )   0.00466(     21     )
#    4         0.0002(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.02 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.12 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      13.9   1000.0     0.0     141.8   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.944162        0.847648      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.822826         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     10.2152         11.2606      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2151(      7     )    4.6665(      7     )
#                                                              0.30976(      8     )   0.10297(     21     )
#    1         0.5133(      8     )    1.4284(      8     )
#                                                              0.18454(      7     )   0.06651(     21     )
#    2         0.1222(      8     )    0.2158(      8     )
#                                                              0.06300(      7     )   0.03146(     21     )
#    3         0.0136(      8     )    0.0132(      8     )
#                                                              0.00701(      7     )   0.00473(     21     )
#    4         0.0002(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.02 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.13 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      15.2   1000.0     0.0     142.3   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.847648        0.824626      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.821615         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     11.2606         12.1993      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2146(      7     )    4.6869(      7     )
#                                                              0.31574(      8     )   0.10488(     21     )
#    1         0.5292(      8     )    1.4677(      8     )
#                                                              0.18604(      7     )   0.06740(     21     )
#    2         0.1260(      8     )    0.2236(      8     )
#                                                              0.06448(      7     )   0.03225(     21     )
#    3         0.0142(      8     )    0.0140(      8     )
#                                                              0.00742(      7     )   0.00500(     21     )
#    4         0.0002(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.02 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.14 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      16.3   1000.0     0.0     142.6   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.824626        0.899620      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.820588         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     12.1993         13.4312      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2177(      7     )    4.7041(      7     )
#                                                              0.32048(      8     )   0.10658(     21     )
#    1         0.5412(      8     )    1.4994(      8     )
#                                                              0.18738(      7     )   0.06814(     21     )
#    2         0.1288(      8     )    0.2301(      8     )
#                                                              0.06583(      7     )   0.03294(     21     )
#    3         0.0148(      8     )    0.0147(      8     )
#                                                              0.00780(      7     )   0.00524(     21     )
#    4         0.0002(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.02 MW      0.01 Mvar      0.03 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.16 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      17.6   1000.0     0.0     143.1   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.899620        0.996431      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.819335         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     13.4312         18.0958      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2532(      7     )    4.7252(      7     )
#                                                              0.32228(      8     )   0.10916(     21     )
#    1         0.5395(      8     )    1.5150(      8     )
#                                                              0.18965(      7     )   0.06882(     21     )
#    2         0.1284(      8     )    0.2348(      8     )
#                                                              0.06809(      7     )   0.03379(     21     )
#    3         0.0150(      8     )    0.0156(      8     )
#                                                              0.00849(      7     )   0.00562(     21     )
#    4         0.0003(      8     )    0.0002(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.03 MW      0.02 Mvar      0.03 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.18 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      22.7   1000.0     0.0     145.0   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.996431        0.841547      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.814186         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     18.0958         20.7379      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2414(      7     )    4.8119(      7     )
#                                                              0.35183(      8     )   0.11812(     21     )
#    1         0.6230(      8     )    1.7157(      8     )
#                                                              0.19589(      7     )   0.07299(     21     )
#    2         0.1481(      8     )    0.2752(      8     )
#                                                              0.07487(      7     )   0.03751(     21     )
#    3         0.0185(      8     )    0.0203(      8     )
#                                                              0.01071(      7     )   0.00705(     21     )
#    4         0.0004(      8     )    0.0003(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.04 MW      0.03 Mvar      0.05 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.29 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      25.9   1000.0     0.0     146.3   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.841547        0.841083      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.810943         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     20.7379         16.3616      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1734(      7     )    4.8665(      7     )
#                                                              0.38150(      8     )   0.12398(     21     )
#    1         0.7225(      8     )    1.9218(      8     )
#                                                              0.20066(      8     )   0.07646(     21     )
#    2         0.1718(      8     )    0.3150(      8     )
#                                                              0.07877(      8     )   0.04024(     21     )
#    3         0.0224(      8     )    0.0245(      8     )
#                                                              0.01194(      7     )   0.00802(     21     )
#    4         0.0005(      8     )    0.0003(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.05 MW      0.03 Mvar      0.06 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.38 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      20.9   1000.0     0.0     144.2   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.841083        0.820951      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.816130         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     16.3616         17.1657      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2192(      7     )    4.7791(      7     )
#                                                              0.34358(      8     )   0.11405(     21     )
#    1         0.6037(      8     )    1.6565(      8     )
#                                                              0.19301(      7     )   0.07152(     21     )
#    2         0.1435(      8     )    0.2622(      8     )
#                                                              0.07174(      7     )   0.03605(     21     )
#    3         0.0175(      8     )    0.0185(      8     )
#                                                              0.00962(      7     )   0.00641(     21     )
#    4         0.0003(      8     )    0.0002(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.03 MW      0.02 Mvar      0.04 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.24 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      21.9   1000.0     0.0     144.6   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.820951        0.894458      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.815096         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     17.1657         17.7210      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2171(      7     )    4.7966(      7     )
#                                                              0.34996(      8     )   0.11610(     21     )
#    1         0.6223(      8     )    1.7004(      8     )
#                                                              0.19429(      7     )   0.07244(     21     )
#    2         0.1479(      8     )    0.2710(      8     )
#                                                              0.07315(      7     )   0.03684(     21     )
#    3         0.0183(      8     )    0.0195(      8     )
#                                                              0.01009(      7     )   0.00671(     21     )
#    4         0.0004(      8     )    0.0002(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.04 MW      0.02 Mvar      0.04 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.26 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00      22.4   1000.0     0.0     144.8   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.894458        0.926168      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.814554         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     17.7210         19.2063      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2275(      7     )    4.8057(      7     )
# ...
#     3.75875         3.43071      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1942(      7     )    4.5572(      7     )
#                                                              0.28271(      8     )   0.09314(     21     )
#    1         0.4478(      8     )    1.2529(      8     )
#                                                              0.17611(      7     )   0.06217(     21     )
#    2         0.1070(      8     )    0.1804(      8     )
#                                                              0.05520(      7     )   0.02753(     21     )
#    3         0.0109(      8     )    0.0095(      8     )
#                                                              0.00510(      7     )   0.00350(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.07 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       6.5   1000.0     0.0     139.7   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.846136        0.822568      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.829569         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     3.43071         2.58292      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1881(      7     )    4.5530(      7     )
#                                                              0.28226(      8     )   0.09264(     21     )
#    1         0.4477(      8     )    1.2496(      8     )
#                                                              0.17569(      7     )   0.06203(     21     )
#    2         0.1070(      8     )    0.1796(      8     )
#                                                              0.05484(      7     )   0.02739(     21     )
#    3         0.0108(      8     )    0.0094(      8     )
#                                                              0.00502(      7     )   0.00345(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.07 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       5.6   1000.0     0.0     139.5   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.822568        0.842501      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.830365         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     2.58292         3.29830      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2025(      7     )    4.5395(      7     )
#                                                              0.27742(      8     )   0.09191(     21     )
#    1         0.4333(      8     )    1.2207(      8     )
#                                                              0.17498(      7     )   0.06144(     21     )
#    2         0.1037(      8     )    0.1745(      8     )
#                                                              0.05420(      7     )   0.02694(     21     )
#    3         0.0104(      8     )    0.0090(      8     )
#                                                              0.00489(      7     )   0.00335(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.06 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       6.4   1000.0     0.0     139.7   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.842501        0.920684      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.829690         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     3.29830        0.787264      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1704(      7     )    4.5509(      7     )
#                                                              0.28361(      8     )   0.09207(     21     )
#    1         0.4542(      8     )    1.2564(      8     )
#                                                              0.17524(      7     )   0.06205(     21     )
#    2         0.1085(      8     )    0.1803(      8     )
#                                                              0.05448(      7     )   0.02732(     21     )
#    3         0.0109(      8     )    0.0093(      8     )
#                                                              0.00494(      7     )   0.00342(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.07 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       3.6   1000.0     0.0     138.9   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.920684        0.833046      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.832167         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.787264         2.78871      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2145(      7     )    4.5092(      7     )
#                                                              0.26885(      8     )   0.08988(     21     )
#    1         0.4103(      8     )    1.1691(      8     )
#                                                              0.17301(      7     )   0.06024(     21     )
#    2         0.0985(      8     )    0.1650(      8     )
#                                                              0.05249(      7     )   0.02597(     21     )
#    3         0.0096(      8     )    0.0082(      8     )
#                                                              0.00453(      7     )   0.00310(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.05 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       5.9   1000.0     0.0     139.5   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.833046        0.923164      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.830169         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     2.78871        -1.52895      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1517(      7     )    4.5429(      7     )
#                                                              0.28352(      8     )   0.09099(     21     )
#    1         0.4571(      8     )    1.2542(      8     )
#                                                              0.17434(      7     )   0.06184(     21     )
#    2         0.1091(      8     )    0.1792(      8     )
#                                                              0.05374(      7     )   0.02706(     21     )
#    3         0.0109(      8     )    0.0091(      8     )
#                                                              0.00478(      7     )   0.00333(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.06 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       1.1   1000.0     0.0     138.3   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.923164        0.968090      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.834317         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -1.52895         6.11852      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2675(      7     )    4.4730(      7     )
#                                                              0.25546(      8     )   0.08865(     21     )
#    1         0.3696(      8     )    1.0937(      8     )
#                                                              0.17153(      7     )   0.05874(     21     )
#    2         0.0894(      8     )    0.1523(      8     )
#                                                              0.05118(      7     )   0.02494(     21     )
#    3         0.0086(      8     )    0.0073(      8     )
#                                                              0.00427(      7     )   0.00288(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.05 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       9.4   1000.0     0.0     140.5   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.968090        0.831282      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.827020         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#     6.11852        -2.27611      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1166(      7     )    4.5959(      7     )
#                                                              0.30138(      8     )   0.09473(     21     )
#    1         0.5090(      8     )    1.3652(      8     )
#                                                              0.17771(      7     )   0.06422(     21     )
#    2         0.1210(      8     )    0.1997(      8     )
#                                                              0.05680(      7     )   0.02896(     21     )
#    3         0.0126(      8     )    0.0108(      8     )
#                                                              0.00545(      7     )   0.00382(     21     )
#    4         0.0001(      8     )    0.0001(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.01 Mvar      0.02 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.08 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       0.4   1000.0     0.0     138.2   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.831282        0.830188      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.834925         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -2.27611        -1.73261      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.1962(      7     )    4.4628(      7     )
#                                                              0.25983(      8     )   0.08598(     21     )
#    1         0.3917(      8     )    1.1126(      8     )
#                                                              0.16932(      7     )   0.05861(     21     )
#    2         0.0942(      8     )    0.1536(      8     )
#                                                              0.04946(      7     )   0.02452(     21     )
#    3         0.0088(      8     )    0.0071(      8     )
#                                                              0.00394(      7     )   0.00272(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.04 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       1.0   1000.0     0.0     138.3   9900.0 -9900.0
#
#  Power flow data changed for machine "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.830188        0.888646      PG
#
#  Power flow data changed for bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.834406         1.10000      VM
#
#  Power flow data changed for load "1" at bus 7 [7           138.00]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    -1.73261       -0.527072      PL
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         1.2029(      7     )    4.4715(      7     )
#                                                              0.26126(      8     )   0.08682(     21     )
#    1         0.3940(      8     )    1.1218(      8     )
#                                                              0.17007(      7     )   0.05891(     21     )
#    2         0.0948(      8     )    0.1555(      8     )
#                                                              0.05006(      7     )   0.02479(     21     )
#    3         0.0090(      8     )    0.0073(      8     )
#                                                              0.00405(      7     )   0.00279(     21     )
#    4         0.0001(      8     )    0.0000(      8     )
#
#
#  Reached tolerance in 4 iterations
#
#  Largest mismatch:      0.01 MW      0.00 Mvar      0.01 MVA at bus 8 [8           230.00]
#  System total absolute mismatch:                    0.04 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     1           138.00       2.2   1000.0     0.0     138.6   9900.0 -9900.0

# %% [markdown]
# ---
# ### Reviewing the Simulation Results
#
# Once the simulation and AC injection are complete, we have tools in place to review and assess the impact on our grid. Specifically, the `WecObj._psse_plot_bus` function offers a comprehensive view of the grid's performance at specified bus numbers.
#
# Before we utilize this function, let's gain a deeper understanding of the key parameters we'll be observing:
#
# - **ΔP (Mismatch Delta of Active Power)**: This parameter quantifies the deviation or mismatch of the actual active power (P) from the expected or reference value at a specific bus. Large deviations might indicate imbalances or potential stability issues within the grid.
#
# - **ΔQ (Mismatch Delta of Reactive Power)**: Similarly, this metric captures the deviation of the actual reactive power (Q) from its reference value. Reactive power management is crucial in maintaining the voltage profile of a grid. Observing ΔQ can offer insights into potential voltage stability challenges.
#
# By monitoring these deltas, especially at pivotal points like the swing bus, we can extract vital insights about the grid's health and stability. The swing bus, in particular, acts as a reference point in the grid, balancing power and ensuring stability. Significant variations in its ΔP and ΔQ can be indicative of overarching grid health.
#
# With this context in mind, in the subsequent code cell, we'll utilize the `WecObj._psse_plot_bus` function to visualize these parameters for a chosen bus and time range.

# %%
WecObj._psse_plot_bus(bus_num=1, time=[1, time])

# %%
time = WecObj.wec_list[0].dataframe.time.to_list()[-1]
delta_p = {}
delta_q = {}
for bus in [2, 7]:
    WecObj._psse_plot_bus(bus_num=bus, time=[750, time], arg_1="ΔP", arg_2="ΔQ")

# %% [markdown]
# ---
# ### Understanding Acceptable Mismatch Values in Power System Simulations
#
# In power system operations, mismatches in power values are inevitable. However, it's essential that these mismatches stay within acceptable limits to ensure stable and reliable grid operations.
#
# **Key Points to Note:**
#
# - **Acceptable Ranges**: For most grid operations, a mismatch value (both ΔP and ΔQ) within the range of ±0.1% of the total system power is deemed acceptable. Values within this range suggest minor deviations, which are manageable and generally do not compromise system integrity.
#
# - **Interpreting Values Within the Range**: Mismatch values within this narrow band reflect a well-balanced system. It indicates that the active and reactive power generated almost perfectly matches the power consumed by loads.
#
# - **Implications of Values Outside the Range**: If mismatches exceed this threshold, it's an indication of potential issues in the grid. These can arise from various factors, including equipment malfunctions, unplanned load changes, or issues with power generation sources.
#
# - **Monitoring and Action**: Continual monitoring of these values is crucial. If values persistently exceed the acceptable range, prompt corrective action or further investigation is necessary to mitigate potential risks to grid stability.
#
# In summary, while minor mismatches in power values are a common occurrence, it's essential that they remain within defined acceptable limits. These defined boundaries ensure the grid's stable operation, even when introducing new elements like WECs.
#
# ---
