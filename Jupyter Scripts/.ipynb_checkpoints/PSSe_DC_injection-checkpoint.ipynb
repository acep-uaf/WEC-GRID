# %%
import sys
sys.path.append('../wec_grid_class.py')

import

import pandas as pd
#import wec_grid_class as wg
import matplotlib.pyplot as plt
import numpy as np
import sqlite3
plt.rcParams["figure.figsize"] = (15,10)

# %%
# Read in case file 
case14 = r"./input_files/case14.raw"

# %%
# initalize WEC GRID Object
pf = wg.Wec_grid(case14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17040\4144900449.py in <module>
#       1 # initalize WEC GRID Object
# ----> 2 pf = wg.Wec_grid(case14)
#
# NameError: name 'wg' is not defined

# %%
# Run first Power Flow and get bus values
pf.run_powerflow
pf.get_values(['BASE', 'PU', 'ANGLED', 'P', 'Q'])
print(pf.dataframe)
# Out:
#        Bus  BASE     PU     ANGLED  Type           P          Q
# 0    BUS 1   0.0  1.060   0.000000     3  232.346268 -16.759069
# 1    BUS 2   0.0  1.045  -4.980000     2   18.393555  29.763643
# 2    BUS 3   0.0  1.010 -12.719999     2  -94.275166   5.310905
# 3    BUS 4   0.0  1.019 -10.330000     1  -47.719318   8.118187
# 4    BUS 5   0.0  1.020  -8.780000     1   -7.731865  -2.865371
# 5    BUS 6   0.0  1.070 -14.220000     2  -11.000880   5.264521
# 6    BUS 7   0.0  1.062 -13.370001     1   -0.245777   0.234765
# 7    BUS 8   0.0  1.090 -13.360000     2    0.114721  17.326178
# 8    BUS 9   0.0  1.056 -14.939999     1  -29.305561   3.840285
# 9   BUS 10   0.0  1.051 -15.100001     1   -9.090860  -5.871971
# 10  BUS 11   0.0  1.057 -14.790001     1   -3.439518  -1.734084
# 11  BUS 12   0.0  1.055 -15.070000     1   -6.009285  -1.676000
# 12  BUS 13   0.0  1.050 -15.159998     1  -13.853797  -6.227429
# 13  BUS 14   0.0  1.036 -16.040001     1  -14.785610  -4.652751

# %%
from IPython.display import IFrame
IFrame(src="https://matpower.app", width='100%', height='600px')
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="https://matpower.app"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# connect to Database and open in df
con = sqlite3.connect('WEC_database.db')
cur = con.cursor()
wec_gen_values = pd.read_sql_query("SELECT * from WecOutput", con)
wec_gen_values
# Out:
#       Time  ibus         P
# 0    300.0   1.0  0.020204
# 1    600.0   1.0  0.013897
# 2    900.0   1.0  0.018099
# 3   1200.0   1.0  0.013920
# 4   1500.0   1.0  0.017861
# 5   1800.0   1.0  0.018624
# 6   2100.0   1.0  0.021036
# 7   2400.0   1.0  0.020560
# 8   2700.0   1.0  0.018935
# 9   3000.0   1.0  0.017833
# 10  3300.0   1.0  0.014170
# 11  3600.0   1.0  0.015578

# %%
plt.plot(wec_gen_values.Time, wec_gen_values.P, marker="o", markersize=10, markerfacecolor="green")
plt.xlabel("Time (sec)")
plt.ylabel("Active Power in MW")
plt.title("WEC: Activate Power Set Points")
# Out:
# Text(0.5, 1.0, 'WEC: Activate Power Set Points')

# %%
time = [] 
history_swing = []
history_injection = []
for i in range(len(wec_gen_values)):
    # choose the next time step set point and run the solver 
    print("Time: {}".format(wec_gen_values.iloc[i].Time))
    print("P setpoint: {}".format(wec_gen_values.iloc[i].P))
    pf.dc_injection(3, wec_gen_values.iloc[i].P)
    #print(pf.dataframe)

    history_swing.append(pf.dataframe.P[0])
    history_injection.append(pf.dataframe.P[2])
    time.append(wec_gen_values.iloc[i].Time)
    print("========================")
# Out:
# Time: 300.0
# P setpoint: 0.020203849487166015
#
#  No power flow data changed for machine "1" at bus 3 [BUS 3             ]
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      5     )    0.0000(      4     )
#                                                              0.00000(      4     )   0.00000(     14     )
#    1         0.0000(      5     )    0.0000(      5     )
#                                                              0.00000(     10     )   0.00000(     12     )
#    2         0.0000(      5     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:      0.00 MW      0.00 Mvar      0.00 MVA at bus 3 [BUS 3             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 600.0
# P setpoint: 0.013897341010994229
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.202038E-01    0.138973E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0001(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00001(      3     )
#    1         0.0000(      3     )    0.0000(     10     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      2     )    0.0000(      7     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:      0.00 MW      0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 900.0
# P setpoint: 0.018099023388648796
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.138973E-01    0.180990E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      7     )
#                                                              0.00000(      5     )   0.00001(      3     )
#    1         0.0000(      3     )    0.0000(      9     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      5     )    0.0000(      4     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:     -0.00 MW     -0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 1200.0
# P setpoint: 0.013920440063701366
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.180990E-01    0.139204E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      4     )
#                                                              0.00000(      5     )   0.00001(      3     )
#    1         0.0000(      3     )    0.0000(     13     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(     10     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:     -0.00 MW     -0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 1500.0
# P setpoint: 0.01786058723259423
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.139204E-01    0.178606E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00001(      3     )
#    1         0.0000(      3     )    0.0000(      9     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      5     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:      0.00 MW      0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 1800.0
# P setpoint: 0.018623693338271248
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.178606E-01    0.186237E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00000(      3     )
#    1         0.0000(      3     )    0.0000(      4     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      5     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:      0.00 MW     -0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 2100.0
# P setpoint: 0.021036469521279168
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.186237E-01    0.210365E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00000(      3     )
#    1         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      5     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:      0.00 MW     -0.00 Mvar      0.00 MVA at bus 2 [BUS 2             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 2400.0
# P setpoint: 0.020559735450852195
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.210365E-01    0.205597E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00000(      3     )
#    1         0.0000(      3     )    0.0000(      4     )
#                                                              0.00000(      3     )   0.00000(     13     )
#    2         0.0000(      5     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:      0.00 MW     -0.00 Mvar      0.00 MVA at bus 2 [BUS 2             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 2700.0
# P setpoint: 0.01893514407280851
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.205597E-01    0.189351E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00000(      3     )
#    1         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      9     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:     -0.00 MW      0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 3000.0
# P setpoint: 0.01783256485431373
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.189351E-01    0.178326E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00000(      3     )
#    1         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      5     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:     -0.00 MW      0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 3300.0
# P setpoint: 0.014169530830260865
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.178326E-01    0.141695E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00001(      3     )
#    1         0.0000(      3     )    0.0000(      9     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      9     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:      0.00 MW     -0.00 Mvar      0.00 MVA at bus 3 [BUS 3             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================
# Time: 3600.0
# P setpoint: 0.015578466474433113
#
#  Power flow data changed for machine "1" at bus 3 [BUS 3             ]:
#  X--ORIGINAL--X  X-NEW VALUE--X  DATA ITEM
#    0.141695E-01    0.155785E-01  PG
#
#   ITER       DELTAP      BUS         DELTAQ      BUS        DELTA/V/      BUS       DELTAANG      BUS
#    0         0.0000(      3     )    0.0000(      5     )
#                                                              0.00000(      5     )   0.00000(      3     )
#    1         0.0000(      3     )    0.0000(      4     )
#                                                              0.00000(      3     )   0.00000(      3     )
#    2         0.0000(      5     )    0.0000(      5     )
#
#
#  Reached tolerance in 2 iterations
#
#  Largest mismatch:     -0.00 MW      0.00 Mvar      0.00 MVA at bus 9 [BUS 9             ]
#  System total absolute mismatch:                    0.00 MVA
#
#  SWING BUS SUMMARY:
#    BUS#-SCT X-- NAME --X BASKV      PGEN     PMAX    PMIN      QGEN     QMAX    QMIN
#       1     BUS 1                  232.4    332.4     0.0     -16.5*    10.0     0.0
# ========================

# %%
# fig, ax = plt.subplots()
# ax.plot(time, history_swing, "k", linewidth = 2, marker="o", markersize=6, markerfacecolor="green")
# #ax.set_ylim(bottom = 0)
# #plt.plot(time, history_swing, marker="o", markersize=10, markerfacecolor="green")
# plt.xlabel("Time (hours)")
# plt.ylabel("Active Power in MW")
# # plt.title("Swing Bus")
# ax.set_xticks(np.arange(min(time), max(time)+1, 3600))
# ax.set_xticklabels((0,1,2,3,4,5,6))
# fig.suptitle('Swing Bus', fontweight ="bold")

# %%
fig, ax = plt.subplots()
ax.plot(time,  wec_gen_values.pg, "k", linewidth = 2, marker="o", markersize=6, markerfacecolor="green")
#ax.set_ylim(bottom = 0)
#plt.plot(time, history_swing, marker="o", markersize=10, markerfacecolor="green")
plt.xlabel("Time (hours)")
plt.ylabel("Active Power in MW")
# plt.title("Swing Bus")
ax.set_xticks(np.arange(min(time), max(time)+1, 3600))
ax.set_xticklabels((0,1,2,3,4,5,6))
fig.suptitle('WEC Setpoints', fontweight ="bold")
# Out:
# Text(0.5, 0.98, 'WEC Setpoints')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

x = [0,5,9,10,15]
y = [0,1,2,3,4]
fig, ax = plt.subplots()
ax.plot(x,y)
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 0.712123))
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))
plt.show()

# %%
pf.dataframe
# Out:
#        Bus  BASE        PU     ANGLED  Type             P             Q
# 0    BUS 1   0.0  1.060000   0.000000     3  2.323729e+02 -1.654552e+01
# 1    BUS 2   0.0  1.045000  -4.982086     2  1.830001e+01  3.085251e+01
# 2    BUS 3   0.0  1.010000 -12.723429     2 -9.418206e+01  6.067843e+00
# 3    BUS 4   0.0  1.017671 -10.312136     1 -4.779999e+01  3.900000e+00
# 4    BUS 5   0.0  1.019514  -8.773232     1 -7.600002e+00 -1.600001e+00
# 5    BUS 6   0.0  1.070000 -14.220278     2 -1.120000e+01  5.230852e+00
# 6    BUS 7   0.0  1.061520 -13.358887     1  2.842171e-14  9.536743e-07
# 7    BUS 8   0.0  1.090000 -13.358888     2 -3.053113e-14  1.762336e+01
# 8    BUS 9   0.0  1.055932 -14.937793     1 -2.950000e+01  4.584854e+00
# 9   BUS 10   0.0  1.050985 -15.096571     1 -9.000000e+00 -5.800000e+00
# 10  BUS 11   0.0  1.056907 -14.789929     1 -3.500000e+00 -1.800000e+00
# 11  BUS 12   0.0  1.055189 -15.074912     1 -6.100000e+00 -1.600000e+00
# 12  BUS 13   0.0  1.050382 -15.155601     1 -1.350000e+01 -5.800000e+00
# 13  BUS 14   0.0  1.035530 -16.032938     1 -1.490000e+01 -5.000000e+00
